# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from pici.pici import Pici
from pici.communities.oem import OEMCommunityFactory
from pici.communities.osm import OSMCommunityFactory
from pici.communities.preciousplastic import PPCommunityFactory
import pandas as pd

from pici.labelling import InnovationLabels
from pici.datatypes import CommunityDataLevel


import plotly.express as ex
from sklearn import set_config

# %%
from IPython.display import display
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.options.plotting.backend = "plotly"

# %%
pici = Pici(
    communities={
        'OpenEnergyMonitor': OEMCommunityFactory,
        'OpenStreetMap': OSMCommunityFactory,
        'PreciousPlastic': PPCommunityFactory,
    },
    cache_dir='../../../cache',
    start='2017-01-01',
    end='2019-01-01',
    cache_nrows=15000
)

# %%
set_config(display="diagram")

# %%
pipe = pici.pipelines.topics()

# %%
pipe.transform(pici.communities)
# Out:
#                                                                       elaboration - number of words (first)  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor                                  257.0
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor                                  619.0
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                                   47.0
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor                                  172.0
# about-split-core-cts-sct-013-family                OpenEnergyMonitor                                   40.0
# ...                                                                                                     ...
# yucatan-mexico-community-project                   PreciousPlastic                                    179.0
# zagreb-cooperative-space                           PreciousPlastic                                     81.0
# zelenew-basket-extrusion-v4                        PreciousPlastic                                    406.0
# zero-waste-key-tag                                 PreciousPlastic                                    158.0
# zihuatanejo-mexio-here                             PreciousPlastic                                    140.0
#
#                                                                       elaboration - number of words (total)  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor                                 9538.0
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor                                 4571.0
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                                  605.0
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor                                 4313.0
# about-split-core-cts-sct-013-family                OpenEnergyMonitor                                 2084.0
# ...                                                                                                     ...
# yucatan-mexico-community-project                   PreciousPlastic                                    537.0
# zagreb-cooperative-space                           PreciousPlastic                                     81.0
# zelenew-basket-extrusion-v4                        PreciousPlastic                                   1218.0
# zero-waste-key-tag                                 PreciousPlastic                                   3160.0
# zihuatanejo-mexio-here                             PreciousPlastic                                    280.0
#
#                                                                       elaboration - number of words (mean)  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor                            128.891892
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor                            207.772727
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                            302.500000
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor                            113.500000
# about-split-core-cts-sct-013-family                OpenEnergyMonitor                            115.777778
# ...                                                                                                    ...
# yucatan-mexico-community-project                   PreciousPlastic                              179.000000
# zagreb-cooperative-space                           PreciousPlastic                               81.000000
# zelenew-basket-extrusion-v4                        PreciousPlastic                              406.000000
# zero-waste-key-tag                                 PreciousPlastic                              158.000000
# zihuatanejo-mexio-here                             PreciousPlastic                              140.000000
#
#                                                                       elaboration - number of words (min)  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor                                  2.0
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor                                 26.0
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                                 47.0
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor                                  3.0
# about-split-core-cts-sct-013-family                OpenEnergyMonitor                                 20.0
# ...                                                                                                   ...
# yucatan-mexico-community-project                   PreciousPlastic                                  179.0
# zagreb-cooperative-space                           PreciousPlastic                                   81.0
# zelenew-basket-extrusion-v4                        PreciousPlastic                                  406.0
# zero-waste-key-tag                                 PreciousPlastic                                  158.0
# zihuatanejo-mexio-here                             PreciousPlastic                                  140.0
#
#                                                                       elaboration - number of words (max)  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor                                568.0
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor                                619.0
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                                558.0
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor                                419.0
# about-split-core-cts-sct-013-family                OpenEnergyMonitor                                381.0
# ...                                                                                                   ...
# yucatan-mexico-community-project                   PreciousPlastic                                  179.0
# zagreb-cooperative-space                           PreciousPlastic                                   81.0
# zelenew-basket-extrusion-v4                        PreciousPlastic                                  406.0
# zero-waste-key-tag                                 PreciousPlastic                                  158.0
# zihuatanejo-mexio-here                             PreciousPlastic                                  140.0
#
#                                                                       elaboration - number of words (sd)  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor                          103.353313
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor                          153.380078
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                          255.500000
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor                          101.198801
# about-split-core-cts-sct-013-family                OpenEnergyMonitor                           98.215498
# ...                                                                                                  ...
# yucatan-mexico-community-project                   PreciousPlastic                              0.000000
# zagreb-cooperative-space                           PreciousPlastic                              0.000000
# zelenew-basket-extrusion-v4                        PreciousPlastic                              0.000000
# zero-waste-key-tag                                 PreciousPlastic                              0.000000
# zihuatanejo-mexio-here                             PreciousPlastic                              0.000000
#
#                                                                       prestige: replies to topics by initial contributor (mean)  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor                                          73.000000
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor                                          16.909091
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                                          16.333333
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor                                          48.235294
# about-split-core-cts-sct-013-family                OpenEnergyMonitor                                          17.000000
# ...                                                                                                                 ...
# yucatan-mexico-community-project                   PreciousPlastic                                             2.000000
# zagreb-cooperative-space                           PreciousPlastic                                             0.000000
# zelenew-basket-extrusion-v4                        PreciousPlastic                                             5.000000
# zero-waste-key-tag                                 PreciousPlastic                                            19.000000
# zihuatanejo-mexio-here                             PreciousPlastic                                             1.500000
#
#                                                                       prestige: replies to topics by initial contributor (amin)  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor                                               73.0
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor                                                1.0
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                                                1.0
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor                                                3.0
# about-split-core-cts-sct-013-family                OpenEnergyMonitor                                               17.0
# ...                                                                                                                 ...
# yucatan-mexico-community-project                   PreciousPlastic                                                  2.0
# zagreb-cooperative-space                           PreciousPlastic                                                  0.0
# zelenew-basket-extrusion-v4                        PreciousPlastic                                                  2.0
# zero-waste-key-tag                                 PreciousPlastic                                                 19.0
# zihuatanejo-mexio-here                             PreciousPlastic                                                  1.0
#
#                                                                       prestige: replies to topics by initial contributor (amax)  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor                                               73.0
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor                                               26.0
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                                               37.0
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor                                              276.0
# about-split-core-cts-sct-013-family                OpenEnergyMonitor                                               17.0
# ...                                                                                                                 ...
# yucatan-mexico-community-project                   PreciousPlastic                                                  2.0
# zagreb-cooperative-space                           PreciousPlastic                                                  0.0
# zelenew-basket-extrusion-v4                        PreciousPlastic                                                 10.0
# zero-waste-key-tag                                 PreciousPlastic                                                 19.0
# zihuatanejo-mexio-here                             PreciousPlastic                                                  2.0
#
#                                                                       prestige: replies to topics by initial contributor (std)  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor                                           0.000000
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor                                           7.128108
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                                          10.811516
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor                                          65.216859
# about-split-core-cts-sct-013-family                OpenEnergyMonitor                                           0.000000
# ...                                                                                                                 ...
# yucatan-mexico-community-project                   PreciousPlastic                                             0.000000
# zagreb-cooperative-space                           PreciousPlastic                                             0.000000
# zelenew-basket-extrusion-v4                        PreciousPlastic                                             3.000000
# zero-waste-key-tag                                 PreciousPlastic                                             0.000000
# zihuatanejo-mexio-here                             PreciousPlastic                                             0.500000
#
#                                                                       prestige: replies to topics by initial contributor (sum)  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor                                               73.0
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor                                              186.0
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                                               98.0
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor                                              820.0
# about-split-core-cts-sct-013-family                OpenEnergyMonitor                                               17.0
# ...                                                                                                                 ...
# yucatan-mexico-community-project                   PreciousPlastic                                                  2.0
# zagreb-cooperative-space                           PreciousPlastic                                                  0.0
# zelenew-basket-extrusion-v4                        PreciousPlastic                                                 20.0
# zero-waste-key-tag                                 PreciousPlastic                                                 19.0
# zihuatanejo-mexio-here                             PreciousPlastic                                                  3.0
#
#                                                                       number of posts  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor               74
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor               22
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                2
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor               38
# about-split-core-cts-sct-013-family                OpenEnergyMonitor               18
# ...                                                                               ...
# yucatan-mexico-community-project                   PreciousPlastic                  3
# zagreb-cooperative-space                           PreciousPlastic                  1
# zelenew-basket-extrusion-v4                        PreciousPlastic                  3
# zero-waste-key-tag                                 PreciousPlastic                 20
# zihuatanejo-mexio-here                             PreciousPlastic                  2
#
#                                                                       number of contributors  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor                       5
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor                       4
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                       1
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor                      11
# about-split-core-cts-sct-013-family                OpenEnergyMonitor                       5
# ...                                                                                      ...
# yucatan-mexico-community-project                   PreciousPlastic                         3
# zagreb-cooperative-space                           PreciousPlastic                         1
# zelenew-basket-extrusion-v4                        PreciousPlastic                         3
# zero-waste-key-tag                                 PreciousPlastic                         8
# zihuatanejo-mexio-here                             PreciousPlastic                         2
#
#                                                                          first post date  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor 2017-08-10 00:00:00
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor 2018-02-14 00:00:00
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor 2017-01-22 00:00:00
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor 2017-08-15 00:00:00
# about-split-core-cts-sct-013-family                OpenEnergyMonitor 2017-01-16 00:00:00
# ...                                                                                  ...
# yucatan-mexico-community-project                   PreciousPlastic   2018-07-19 05:03:00
# zagreb-cooperative-space                           PreciousPlastic   2018-12-26 18:24:00
# zelenew-basket-extrusion-v4                        PreciousPlastic   2018-06-12 13:24:00
# zero-waste-key-tag                                 PreciousPlastic   2017-02-07 10:11:00
# zihuatanejo-mexio-here                             PreciousPlastic   2018-03-27 20:43:00
#
#                                                                         second post date  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor 2017-08-10 00:00:00
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor 2018-02-14 00:00:00
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor 2017-02-06 00:00:00
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor 2017-08-15 00:00:00
# about-split-core-cts-sct-013-family                OpenEnergyMonitor 2017-01-16 00:00:00
# ...                                                                                  ...
# yucatan-mexico-community-project                   PreciousPlastic   2018-08-19 20:53:00
# zagreb-cooperative-space                           PreciousPlastic   2018-12-26 18:24:00
# zelenew-basket-extrusion-v4                        PreciousPlastic   2018-11-28 00:01:00
# zero-waste-key-tag                                 PreciousPlastic   2017-03-07 17:42:00
# zihuatanejo-mexio-here                             PreciousPlastic   2018-10-16 23:08:00
#
#                                                                           last post date  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor 2017-09-15 00:00:00
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor 2018-02-25 00:00:00
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor 2017-02-06 00:00:00
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor 2018-12-11 00:00:00
# about-split-core-cts-sct-013-family                OpenEnergyMonitor 2017-05-04 00:00:00
# ...                                                                                  ...
# yucatan-mexico-community-project                   PreciousPlastic   2018-08-25 17:35:00
# zagreb-cooperative-space                           PreciousPlastic   2018-12-26 18:24:00
# zelenew-basket-extrusion-v4                        PreciousPlastic   2018-12-13 07:35:00
# zero-waste-key-tag                                 PreciousPlastic   2018-02-19 12:22:00
# zihuatanejo-mexio-here                             PreciousPlastic   2018-10-16 23:08:00
#
#                                                                       delay first last post  \
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor                     36
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor                     11
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                     15
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor                    483
# about-split-core-cts-sct-013-family                OpenEnergyMonitor                    108
# ...                                                                                     ...
# yucatan-mexico-community-project                   PreciousPlastic                       37
# zagreb-cooperative-space                           PreciousPlastic                        0
# zelenew-basket-extrusion-v4                        PreciousPlastic                      183
# zero-waste-key-tag                                 PreciousPlastic                      377
# zihuatanejo-mexio-here                             PreciousPlastic                      203
#
#                                                                       delay first second post
# topic_slug                                         community_name
# 3-phase-whole-house-pv-and-heat-pump-monitoring... OpenEnergyMonitor                        0
# 4-ct-emonbase-using-emontx-and-pi-zero-w           OpenEnergyMonitor                        0
# a-howto-install-freeboard-with-mqtt-for-emontx-... OpenEnergyMonitor                       15
# a-taste-of-things-to-come-uk-smart-meter-data-a... OpenEnergyMonitor                        0
# about-split-core-cts-sct-013-family                OpenEnergyMonitor                        0
# ...                                                                                       ...
# yucatan-mexico-community-project                   PreciousPlastic                         31
# zagreb-cooperative-space                           PreciousPlastic                          0
# zelenew-basket-extrusion-v4                        PreciousPlastic                        168
# zero-waste-key-tag                                 PreciousPlastic                         28
# zihuatanejo-mexio-here                             PreciousPlastic                        203
#
# [2077 rows x 18 columns]
